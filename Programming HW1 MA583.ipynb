# %% [markdown]
# # Programming Assignment: Numerical Optimization for Logistic Regression.
#
# ### Name: Elliot Frost

# %% [markdown]
# ## 0. You will do the following:
#
# 1. Read the lecture note: [click here](https://github.com/wangshusen/DeepLearning/blob/master/LectureNotes/Logistic/paper/logistic.pdf)
#
# 2. Read, complete, and run my code.
#
# 3. **Implement mini-batch SGD** and evaluate the performance.
#
# 4. Convert the .IPYNB file to .HTML file.
#
#     * The HTML file must contain **the code** and **the output after execution**.
#
#     * Missing **the output after execution** will not be graded.
#
#
# 5. Upload this .HTML file to your Google Drive, Dropbox, or your Github repo.  (If you submit the file to Google Drive or Dropbox, you must make the file "open-access". The delay caused by "deny of access" may result in late penalty.)
#
# 6. On Canvas, submit the Google Drive/Dropbox/Github link to the HTML file.
#
#
# ## Grading criteria:
#
# 1. When computing the ```gradient``` and ```objective function value``` using a batch of samples, use **matrix-vector multiplication** rather than a FOR LOOP of **vector-vector multiplications**.
#
# 2. Plot ```objective function value``` against ```epochs```. In the plot, compare GD, SGD, and MB-SGD (with $b=8$ and $b=64$). The plot must look reasonable.

# %% [markdown]
# # 1. Data processing
#
# - Download the Diabete dataset from https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/diabetes
# - Load the data using sklearn.
# - Preprocess the data.

# %% [markdown]
# ## 1.1. Load the data

# %%
from sklearn import datasets
import numpy

x_sparse, y = datasets.load_svmlight_file('diabetes')
x = x_sparse.todense()

print('Shape of x: ' + str(x.shape))
print('Shape of y: ' + str(y.shape))
# Out:
# Shape of x: (768, 8)
# Shape of y: (768,)

# %% [markdown]
# ## 1.2. Partition to training and test sets

# %%
# partition the data to training and test sets
n = x.shape[0]
n_train = 640
n_test = n - n_train

rand_indices = numpy.random.permutation(n)
train_indices = rand_indices[0:n_train]
test_indices = rand_indices[n_train:n]

x_train = x[train_indices, :]
x_test = x[test_indices, :]
y_train = y[train_indices].reshape(n_train, 1)
y_test = y[test_indices].reshape(n_test, 1)

print('Shape of x_train: ' + str(x_train.shape))
print('Shape of x_test: ' + str(x_test.shape))
print('Shape of y_train: ' + str(y_train.shape))
print('Shape of y_test: ' + str(y_test.shape))
# Out:
# Shape of x_train: (640, 8)
# Shape of x_test: (128, 8)
# Shape of y_train: (640, 1)
# Shape of y_test: (128, 1)

# %% [markdown]
# ## 1.3. Feature scaling

# %% [markdown]
# Use the standardization to trainsform both training and test features

# %%
# Standardization
import numpy

# calculate mu and sig using the training set
d = x_train.shape[1]
mu = numpy.mean(x_train, axis=0).reshape(1, d)
sig = numpy.std(x_train, axis=0).reshape(1, d)

# transform the training features
x_train = (x_train - mu) / (sig + 1E-6)

# transform the test features
x_test = (x_test - mu) / (sig + 1E-6)

print('test mean = ')
print(numpy.mean(x_test, axis=0))

print('test std = ')
print(numpy.std(x_test, axis=0))
# Out:
# test mean =
# [[-0.03390068  0.01849813 -0.0657962  -0.03193428  0.08552164 -0.08141368
#    0.11975236 -0.03373851]]
# test std =
# [[1.00446351 0.95607218 0.91930656 0.95895361 1.10829185 0.9859874
#   1.18394699 1.06403599]]

# %% [markdown]
# ## 1.4. Add a dimension of all ones

# %%
n_train, d = x_train.shape
x_train = numpy.concatenate((x_train, numpy.ones((n_train, 1))), axis=1)

n_test, d = x_test.shape
x_test = numpy.concatenate((x_test, numpy.ones((n_test, 1))), axis=1)

print('Shape of x_train: ' + str(x_train.shape))
print('Shape of x_test: ' + str(x_test.shape))
# Out:
# Shape of x_train: (640, 9)
# Shape of x_test: (128, 9)

# %% [markdown]
# # 2. Logistic regression model
#
# The objective function is $Q (w; X, y) = \frac{1}{n} \sum_{i=1}^n \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $.

# %%
# Calculate the objective function value
# Inputs:
#     w: d-by-1 matrix
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
# Return:
#     objective function value (scalar)
def objective(w, x, y, lam):
    n, d = x.shape
    yx = numpy.multiply(y, x) # n-by-d matrix
    yxw = numpy.dot(yx, w) # n-by-1 matrix
    vec1 = numpy.exp(-yxw) # n-by-1 matrix
    vec2 = numpy.log(1 + vec1) # n-by-1 matrix
    loss = numpy.mean(vec2) # scalar
    reg = lam / 2 * numpy.sum(w * w) # scalar
    return loss + reg

# %%
# initialize w
d = x_train.shape[1]
w = numpy.zeros((d, 1))

# evaluate the objective function value at w
lam = 1E-6
objval0 = objective(w, x_train, y_train, lam)
print('Initial objective function value = ' + str(objval0))
# Out:
# Initial objective function value = 0.6931471805599453

# %% [markdown]
# # 3. Numerical optimization

# %% [markdown]
# ## 3.1. Gradient descent

# %% [markdown]
# The gradient at $w$ is $g = - \frac{1}{n} \sum_{i=1}^n \frac{y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$

# %%
# Calculate the gradient
# Inputs:
#     w: d-by-1 matrix
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
# Return:
#     g: g: d-by-1 matrix, full gradient
def gradient(w, x, y, lam):
    n, d = x.shape
    yx = numpy.multiply(y, x) # n-by-d matrix
    yxw = numpy.dot(yx, w) # n-by-1 matrix
    vec1 = numpy.exp(yxw) # n-by-1 matrix
    vec2 = numpy.divide(yx, 1+vec1) # n-by-d matrix
    vec3 = -numpy.mean(vec2, axis=0).reshape(d, 1) # d-by-1 matrix
    g = vec3 + lam * w
    return g

# %%
# Gradient descent for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     stepsize: scalar
#     max_iter: integer, the maximal iterations
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: d-by-1 matrix, the solution
#     objvals: a record of each iteration's objective value
def grad_descent(x, y, lam, stepsize, max_iter=100, w=None):
    n, d = x.shape
    objvals = numpy.zeros(max_iter) # store the objective values
    if w is None:
        w = numpy.zeros((d, 1)) # zero initialization
    
    for t in range(max_iter):
        objval = objective(w, x, y, lam)
        objvals[t] = objval
        print('Objective value at t=' + str(t) + ' is ' + str(objval))
        g = gradient(w, x, y, lam)
        w -= stepsize * g
    
    return w, objvals

# %% [markdown]
# Run gradient descent.

# %%
lam = 1E-6
stepsize = 1.0
w, objvals_gd = grad_descent(x_train, y_train, lam, stepsize)
# Out:
# Objective value at t=0 is 0.6931471805599453
# Objective value at t=1 is 0.5867954110433863
# Objective value at t=2 is 0.5430113920274318
# Objective value at t=3 is 0.5193068950442893
# Objective value at t=4 is 0.5044448006442771
# Objective value at t=5 is 0.4943475920232236
# Objective value at t=6 is 0.4871412576861412
# Objective value at t=7 is 0.4818236466902392
# Objective value at t=8 is 0.4778027249573179
# Objective value at t=9 is 0.47470416896358675
# Objective value at t=10 is 0.4722795884237516
# Objective value at t=11 is 0.4703581096678266
# Objective value at t=12 is 0.4688188324609027
# Objective value at t=13 is 0.46757424194377095
# Objective value at t=14 is 0.46655977015719075
# Objective value at t=15 is 0.46572699569022236
# Objective value at t=16 is 0.46503908684351997
# Objective value at t=17 is 0.46446767533951333
# Objective value at t=18 is 0.46399066772302067
# Objective value at t=19 is 0.46359068590653046
# Objective value at t=20 is 0.46325393844300294
# Objective value at t=21 is 0.46296939197189385
# Objective value at t=22 is 0.4627281552051805
# Objective value at t=23 is 0.46252301558135633
# Objective value at t=24 is 0.4623480870270651
# Objective value at t=25 is 0.4621985395575774
# Objective value at t=26 is 0.4620703898289825
# Objective value at t=27 is 0.46196033755328214
# Objective value at t=28 is 0.46186563675219183
# Objective value at t=29 is 0.4617839937099153
# Objective value at t=30 is 0.46171348555559216
# Objective value at t=31 is 0.4616524949082016
# Objective value at t=32 is 0.46159965711738504
# Objective value at t=33 is 0.4615538174478033
# Objective value at t=34 is 0.4615139961621936
# Objective value at t=35 is 0.4614793599154534
# Objective value at t=36 is 0.46144919821878566
# Objective value at t=37 is 0.46142290399782676
# Objective value at t=38 is 0.4613999574724832
# Objective value at t=39 is 0.4613799127440435
# Objective value at t=40 is 0.4613623865981395
# Objective value at t=41 is 0.46134704912857
# Objective value at t=42 is 0.46133361586302274
# Objective value at t=43 is 0.4613218411319884
# Objective value at t=44 is 0.4613115124701557
# Objective value at t=45 is 0.46130244587799096
# Objective value at t=46 is 0.46129448180209015
# Objective value at t=47 is 0.4612874817178329
# Objective value at t=48 is 0.4612813252180839
# Objective value at t=49 is 0.46127590752814335
# Objective value at t=50 is 0.46127113738059466
# Objective value at t=51 is 0.46126693519471595
# Objective value at t=52 is 0.4612632315141856
# Objective value at t=53 is 0.46125996566429467
# Objective value at t=54 is 0.4612570845960663
# Objective value at t=55 is 0.46125454188982457
# Objective value at t=56 is 0.46125229689502306
# Objective value at t=57 is 0.4612503139867256
# Objective value at t=58 is 0.4612485619221037
# Objective value at t=59 is 0.461247013282827
# Objective value at t=60 is 0.4612456439913256
# Objective value at t=61 is 0.461244432890674
# Objective value at t=62 is 0.4612433613793459
# Objective value at t=63 is 0.4612424130933503
# Objective value at t=64 is 0.4612415736293383
# Objective value at t=65 is 0.4612408303031731
# Objective value at t=66 is 0.4612401719392364
# Objective value at t=67 is 0.4612395886864023
# Objective value at t=68 is 0.4612390718571708
# Objective value at t=69 is 0.46123861378693753
# Objective value at t=70 is 0.4612382077107881
# Objective value at t=71 is 0.4612378476555543
# Objective value at t=72 is 0.4612375283451801
# Objective value at t=73 is 0.4612372451176997
# Objective value at t=74 is 0.4612369938523562
# Objective value at t=75 is 0.4612367709055857
# Objective value at t=76 is 0.4612365730547526
# Objective value at t=77 is 0.4612363974486737
# Objective value at t=78 is 0.4612362415640851
# Objective value at t=79 is 0.4612361031673209
# Objective value at t=80 is 0.46123598028056234
# Objective value at t=81 is 0.4612358711520985
# Objective value at t=82 is 0.461235774230109
# Objective value at t=83 is 0.46123568813954346
# Objective value at t=84 is 0.4612356116617216
# Objective value at t=85 is 0.4612355437163279
# Objective value at t=86 is 0.461235483345513
# Objective value at t=87 is 0.46123542969985104
# Objective value at t=88 is 0.4612353820259306
# Objective value at t=89 is 0.4612353396553872
# Objective value at t=90 is 0.4612353019952058
# Objective value at t=91 is 0.4612352685191429
# Objective value at t=92 is 0.46123523876013955
# Objective value at t=93 is 0.4612352123036045
# Objective value at t=94 is 0.4612351887814711
# Objective value at t=95 is 0.4612351678669329
# Objective value at t=96 is 0.46123514926978304
# Objective value at t=97 is 0.4612351327322842
# Objective value at t=98 is 0.4612351180255101
# Objective value at t=99 is 0.4612351049461025

# %% [markdown]
# ## 3.2. Stochastic gradient descent (SGD)
#
# Define $Q_i (w) = \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $.
#
# The stochastic gradient at $w$ is $g_i = \frac{\partial Q_i }{ \partial w} = -\frac{y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$.

# %%
# Calculate the objective Q_i and the gradient of Q_i
# Inputs:
#     w: d-by-1 matrix
#     xi: 1-by-d matrix
#     yi: scalar
#     lam: scalar, the regularization parameter
# Return:
#     obj: scalar, the objective Q_i
#     g: d-by-1 matrix, gradient of Q_i
def stochastic_objective_gradient(w, xi, yi, lam):
    yx = yi * xi # 1-by-d matrix
    yxw = float(numpy.dot(yx, w)) # scalar
    
    # calculate objective function Q_i
    loss = numpy.log(1 + numpy.exp(-yxw)) # scalar
    reg = lam / 2 * numpy.sum(w * w) # scalar
    obj = loss + reg
    
    # calculate stochastic gradient
    g_loss = -yx.T / (1 + numpy.exp(yxw)) # d-by-1 matrix
    g = g_loss + lam * w # d-by-1 matrix
    
    return obj, g

# %%
# SGD for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     stepsize: scalar
#     max_epoch: integer, the maximal epochs
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: the solution
#     objvals: record of each iteration's objective value
def sgd(x, y, lam, stepsize, max_epoch=100, w=None):
    n, d = x.shape
    objvals = numpy.zeros(max_epoch) # store the objective values
    if w is None:
        w = numpy.zeros((d, 1)) # zero initialization
    
    for t in range(max_epoch):
        # randomly shuffle the samples
        rand_indices = numpy.random.permutation(n)
        x_rand = x[rand_indices, :]
        y_rand = y[rand_indices, :]
        
        objval = 0 # accumulate the objective values
        for i in range(n):
            xi = x_rand[i, :] # 1-by-d matrix
            yi = float(y_rand[i, :]) # scalar
            obj, g = stochastic_objective_gradient(w, xi, yi, lam)
            objval += obj
            w -= stepsize * g
        
        stepsize *= 0.9 # decrease step size
        objval /= n
        objvals[t] = objval
        print('Objective value at epoch t=' + str(t) + ' is ' + str(objval))
    
    return w, objvals

# %% [markdown]
# Run SGD.

# %%
lam = 1E-6
stepsize = 0.1
w, objvals_sgd = sgd(x_train, y_train, lam, stepsize)
# Out:
# Objective value at epoch t=0 is 0.521381303087607
# Objective value at epoch t=1 is 0.5051527604316608
# Objective value at epoch t=2 is 0.5001342294696849
# Objective value at epoch t=3 is 0.5027457353785094
# Objective value at epoch t=4 is 0.4957114061053048
# Objective value at epoch t=5 is 0.49354460414133794
# Objective value at epoch t=6 is 0.4833189721724061
# Objective value at epoch t=7 is 0.4863851331560838
# Objective value at epoch t=8 is 0.4842031672337181
# Objective value at epoch t=9 is 0.4782264805672674
# Objective value at epoch t=10 is 0.48152423891813756
# Objective value at epoch t=11 is 0.47818286549367156
# Objective value at epoch t=12 is 0.4770115434880431
# Objective value at epoch t=13 is 0.4762769663023151
# Objective value at epoch t=14 is 0.4738439543026109
# Objective value at epoch t=15 is 0.47254950543299296
# Objective value at epoch t=16 is 0.4720977569242164
# Objective value at epoch t=17 is 0.47216868605599965
# Objective value at epoch t=18 is 0.47085864427866014
# Objective value at epoch t=19 is 0.4692601887240369
# Objective value at epoch t=20 is 0.46872428726845367
# Objective value at epoch t=21 is 0.4684908973250579
# Objective value at epoch t=22 is 0.46712399712994435
# Objective value at epoch t=23 is 0.4661844472103778
# Objective value at epoch t=24 is 0.46674938340618083
# Objective value at epoch t=25 is 0.466117603335291
# Objective value at epoch t=26 is 0.4654637296010017
# Objective value at epoch t=27 is 0.46510745359303013
# Objective value at epoch t=28 is 0.464800163192824
# Objective value at epoch t=29 is 0.46448104173041366
# Objective value at epoch t=30 is 0.4638205416591233
# Objective value at epoch t=31 is 0.4638571824005721
# Objective value at epoch t=32 is 0.46350534779085867
# Objective value at epoch t=33 is 0.46322333031457674
# Objective value at epoch t=34 is 0.46309127835481456
# Objective value at epoch t=35 is 0.4629173061666713
# Objective value at epoch t=36 is 0.46278824265397234
# Objective value at epoch t=37 is 0.4626484018043879
# Objective value at epoch t=38 is 0.462435071683133
# Objective value at epoch t=39 is 0.4623732245946795
# Objective value at epoch t=40 is 0.46225997025491605
# Objective value at epoch t=41 is 0.46214027280792075
# Objective value at epoch t=42 is 0.4620589639491664
# Objective value at epoch t=43 is 0.4619876690136451
# Objective value at epoch t=44 is 0.4619029387363712
# Objective value at epoch t=45 is 0.46184656623178855
# Objective value at epoch t=46 is 0.4617850481598806
# Objective value at epoch t=47 is 0.46172185836118845
# Objective value at epoch t=48 is 0.46168181241180334
# Objective value at epoch t=49 is 0.46163213698299954
# Objective value at epoch t=50 is 0.4615970691055097
# Objective value at epoch t=51 is 0.4615608027140783
# Objective value at epoch t=52 is 0.4615286549411902
# Objective value at epoch t=53 is 0.4614998502582689
# Objective value at epoch t=54 is 0.4614716153374788
# Objective value at epoch t=55 is 0.46144918125079204
# Objective value at epoch t=56 is 0.4614279447968796
# Objective value at epoch t=57 is 0.4614084208140928
# Objective value at epoch t=58 is 0.4613915739301121
# Objective value at epoch t=59 is 0.46137556344723263
# Objective value at epoch t=60 is 0.46136163787692536
# Objective value at epoch t=61 is 0.461349097843768
# Objective value at epoch t=62 is 0.46133746525263747
# Objective value at epoch t=63 is 0.46132755223496236
# Objective value at epoch t=64 is 0.46131806422279464
# Objective value at epoch t=65 is 0.4613100880567229
# Objective value at epoch t=66 is 0.461302613397711
# Objective value at epoch t=67 is 0.46129582243981015
# Objective value at epoch t=68 is 0.4612898191700071
# Objective value at epoch t=69 is 0.4612843476285974
# Objective value at epoch t=70 is 0.4612794665046507
# Objective value at epoch t=71 is 0.4612750529145977
# Objective value at epoch t=72 is 0.4612710775243908
# Objective value at epoch t=73 is 0.461267510677262
# Objective value at epoch t=74 is 0.46126430247737354
# Objective value at epoch t=75 is 0.46126138797843685
# Objective value at epoch t=76 is 0.4612587890212317
# Objective value at epoch t=77 is 0.46125644453805703
# Objective value at epoch t=78 is 0.46125432549113654
# Objective value at epoch t=79 is 0.46125242964984803
# Objective value at epoch t=80 is 0.46125071745354235
# Objective value at epoch t=81 is 0.46124917189990955
# Objective value at epoch t=82 is 0.4612477924988031
# Objective value at epoch t=83 is 0.4612465408957639
# Objective value at epoch t=84 is 0.46124541828806986
# Objective value at epoch t=85 is 0.4612444083122729
# Objective value at epoch t=86 is 0.46124349769536677
# Objective value at epoch t=87 is 0.4612426790028863
# Objective value at epoch t=88 is 0.46124194145974445
# Objective value at epoch t=89 is 0.46124127844299834
# Objective value at epoch t=90 is 0.46124068182187444
# Objective value at epoch t=91 is 0.46124014445586975
# Objective value at epoch t=92 is 0.46123966075112255
# Objective value at epoch t=93 is 0.4612392250242772
# Objective value at epoch t=94 is 0.46123883340385446
# Objective value at epoch t=95 is 0.46123848082265945
# Objective value at epoch t=96 is 0.46123816345484797
# Objective value at epoch t=97 is 0.46123787794159676
# Objective value at epoch t=98 is 0.46123762083006536
# Objective value at epoch t=99 is 0.4612373894773468

# %% [markdown]
# # 4. Compare GD with SGD
#
# Plot objective function values against epochs.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(6, 4))

epochs_gd = range(len(objvals_gd))
epochs_sgd = range(len(objvals_sgd))

line0, = plt.plot(epochs_gd, objvals_gd, '--b', LineWidth=4)
line1, = plt.plot(epochs_sgd, objvals_sgd, '-r', LineWidth=2)
plt.xlabel('Epochs', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1], ['GD', 'SGD'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('compare_gd_sgd.pdf', format='pdf', dpi=1200)

# %% [markdown]
# # 5. Prediction

# %%
# Predict class label
# Inputs:
#     w: d-by-1 matrix
#     X: m-by-d matrix
# Return:
#     f: m-by-1 matrix, the predictions
def predict(w, X):
    xw = numpy.dot(X, w)
    f = numpy.sign(xw)
    return f

# %%
# evaluate training error
f_train = predict(w, x_train)
diff = numpy.abs(f_train - y_train) / 2
error_train = numpy.mean(diff)
print('Training classification error is ' + str(error_train))
# Out:
# Training classification error is 0.209375

# %%
# evaluate test error
f_test = predict(w, x_test)
diff = numpy.abs(f_test - y_test) / 2
error_test = numpy.mean(diff)
print('Test classification error is ' + str(error_test))
# Out:
# Test classification error is 0.2578125

# %% [markdown]
# # 6. Mini-batch SGD (fill the code)

# %% [markdown]
# ## 6.1. Compute the objective $Q_I$ and its gradient using a batch of samples
#
# Define $Q_I (w) = \frac{1}{b} \sum_{i \in I} \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $, where $I$ is a set containing $b$ indices randomly drawn from $\{ 1, \cdots , n \}$ without replacement.
#
# The stochastic gradient at $w$ is $g_I = \frac{\partial Q_I }{ \partial w} = \frac{1}{b} \sum_{i \in I} \frac{- y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$.

# %%
# Calculate the objective Q_I and the gradient of Q_I
# Inputs:
#     w: d-by-1 matrix
#     xi: b-by-d matrix
#     yi: b-by-1 matrix
#     lam: scalar, the regularization parameter
#     b: integer, the batch size
# Return:
#     obj: scalar, the objective Q_i
#     g: d-by-1 matrix, gradient of Q_i
def mb_stochastic_objective_gradient(w, xi, yi, lam, b):
    # Fill the function
    # Follow the implementation of stochastic_objective_gradient
    # Use matrix-vector multiplication; do not use FOR LOOP of vector-vector multiplications
    xiShape = xi.shape[1]
    xy = numpy.multiply(yi, xi)
    yxw = numpy.dot(xy, w)
    lossFunction = numpy.mean(numpy.log(1 + numpy.exp(-yxw)))
    reg = lam / 2 * numpy.sum(w * w) 
    obj = lossFunction + reg
    vector1 = numpy.exp(yxw) # b-by-1 matrix
    vector2 = numpy.divide(xy, 1 + vector1) # b-by-d matrix
    vector3 = -numpy.mean(vector2, axis=0).reshape(d, 1) # d-by-1 matrix    
    g = vector3 + lam * w # d-by-1 matrix
    return obj, g

# %% [markdown]
# ## 6.2. Implement mini-batch SGD
#
# Hints:
# 1. In every epoch, randomly permute the $n$ samples (just like SGD).
# 2. Each epoch has $\frac{n}{b}$ iterations. In every iteration, use $b$ samples, and compute the gradient and objective using the ``mb_stochastic_objective_gradient`` function. In the next iteration, use the next $b$ samples, and so on.

# %%
# Mini-Batch SGD for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     b: integer, the batch size
#     stepsize: scalar
#     max_epoch: integer, the maximal epochs
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: the solution
#     objvals: record of each iteration's objective value
def mb_sgd(x, y, lam, b, stepsize, max_epoch=100, w=None):
    # Fill the function
    # Follow the implementation of sgd
    # Record one objective value per epoch (not per iteration!)
    ss= stepsize
    n, d = x.shape
    objvals = numpy.zeros(max_epoch)
    if w is None:
        w = numpy.zeros((d, 1))
    
    for t in range(max_epoch):
        indexes = numpy.random.permutation(n).reshape((n // b, b))
        objval = 0
        for i in indexes:
            xi = x[i, :]
            yi = y[i, :]            
            obj, g = mb_stochastic_objective_gradient(w, xi, yi, lam, b)
            objval += obj
            w -= ss * g
            
        ss *= 0.9 
        objval /= n / b
        objvals[t] = objval
        print('epoch number' + str(t) )
        print(' epoch value ' + str(objval))    
    return w, objvals

# %% [markdown]
# ## 6.3. Run MB-SGD

# %%
# MB-SGD with batch size b=8
lam = 1E-6 # do not change
b = 8 # do not change
stepsize = 0.1 # you must tune this parameter

w, objvals_mbsgd8 = mb_sgd(x_train, y_train, lam, b, stepsize)
# Out:
# epoch number0
#  epoch value 0.53926666522409
# epoch number1
#  epoch value 0.47823287383349483
# epoch number2
#  epoch value 0.4699677150394222
# epoch number3
#  epoch value 0.4677971694332845
# epoch number4
#  epoch value 0.4671029462168684
# epoch number5
#  epoch value 0.465928086178358
# epoch number6
#  epoch value 0.4656382637710778
# epoch number7
#  epoch value 0.4652742589468115
# epoch number8
#  epoch value 0.46449588953596077
# epoch number9
#  epoch value 0.46478414639380194
# epoch number10
#  epoch value 0.46432512147950444
# epoch number11
#  epoch value 0.4636172110493025
# epoch number12
#  epoch value 0.4637518843613669
# epoch number13
#  epoch value 0.4634750163779612
# epoch number14
#  epoch value 0.46309816060199305
# epoch number15
#  epoch value 0.46277783026152
# epoch number16
#  epoch value 0.46279813559167743
# epoch number17
#  epoch value 0.462557465961685
# epoch number18
#  epoch value 0.46244566450493707
# epoch number19
#  epoch value 0.462367252282908
# epoch number20
#  epoch value 0.4623368684906681
# epoch number21
#  epoch value 0.46206749868664765
# epoch number22
#  epoch value 0.46210781983739135
# epoch number23
#  epoch value 0.46206776410994654
# epoch number24
#  epoch value 0.461926460670005
# epoch number25
#  epoch value 0.461861503749269
# epoch number26
#  epoch value 0.46181343440594713
# epoch number27
#  epoch value 0.4617314894138945
# epoch number28
#  epoch value 0.4616771577005113
# epoch number29
#  epoch value 0.4616400595864906
# epoch number30
#  epoch value 0.4615823738968158
# epoch number31
#  epoch value 0.4615699021177472
# epoch number32
#  epoch value 0.4615563553131781
# epoch number33
#  epoch value 0.4615247921736637
# epoch number34
#  epoch value 0.46149001424372066
# epoch number35
#  epoch value 0.4614626043736919
# epoch number36
#  epoch value 0.46143162503618446
# epoch number37
#  epoch value 0.4614099644627599
# epoch number38
#  epoch value 0.4613957069874021
# epoch number39
#  epoch value 0.4613707190650692
# epoch number40
#  epoch value 0.46137274008165763
# epoch number41
#  epoch value 0.4613458067881336
# epoch number42
#  epoch value 0.46134744081083834
# epoch number43
#  epoch value 0.46133368684989967
# epoch number44
#  epoch value 0.4613240553775818
# epoch number45
#  epoch value 0.46130843550935385
# epoch number46
#  epoch value 0.46130523084203856
# epoch number47
#  epoch value 0.461297046936257
# epoch number48
#  epoch value 0.46129354301058784
# epoch number49
#  epoch value 0.4612899746263913
# epoch number50
#  epoch value 0.4612852707784737
# epoch number51
#  epoch value 0.4612797737557616
# epoch number52
#  epoch value 0.46127002915856696
# epoch number53
#  epoch value 0.46126984049291686
# epoch number54
#  epoch value 0.4612666477849137
# epoch number55
#  epoch value 0.46126277495454077
# epoch number56
#  epoch value 0.46126275973465647
# epoch number57
#  epoch value 0.4612580401288569
# epoch number58
#  epoch value 0.4612549136024671
# epoch number59
#  epoch value 0.461253886731404
# epoch number60
#  epoch value 0.46125316748565953
# epoch number61
#  epoch value 0.4612506878860539
# epoch number62
#  epoch value 0.4612498554643107
# epoch number63
#  epoch value 0.4612485500025706
# epoch number64
#  epoch value 0.46124637295698534
# epoch number65
#  epoch value 0.46124677443116646
# epoch number66
#  epoch value 0.46124451503218405
# epoch number67
#  epoch value 0.4612439047739752
# epoch number68
#  epoch value 0.46124313257258776
# epoch number69
#  epoch value 0.46124280944399415
# epoch number70
#  epoch value 0.46124217841920584
# epoch number71
#  epoch value 0.4612413283113079
# epoch number72
#  epoch value 0.46124112672843154
# epoch number73
#  epoch value 0.46124061462566635
# epoch number74
#  epoch value 0.4612404269044039
# epoch number75
#  epoch value 0.4612399634015388
# epoch number76
#  epoch value 0.4612395527901844
# epoch number77
#  epoch value 0.4612392461074005
# epoch number78
#  epoch value 0.46123910284328334
# epoch number79
#  epoch value 0.4612388049075894
# epoch number80
#  epoch value 0.46123867861244144
# epoch number81
#  epoch value 0.46123841773313445
# epoch number82
#  epoch value 0.4612382302578978
# epoch number83
#  epoch value 0.4612381534232476
# epoch number84
#  epoch value 0.4612379590795455
# epoch number85
#  epoch value 0.4612378658650712
# epoch number86
#  epoch value 0.46123776943913414
# epoch number87
#  epoch value 0.46123758387391706
# epoch number88
#  epoch value 0.4612375681866725
# epoch number89
#  epoch value 0.46123741188737133
# epoch number90
#  epoch value 0.46123730064927243
# epoch number91
#  epoch value 0.4612373132250366
# epoch number92
#  epoch value 0.4612372712372451
# epoch number93
#  epoch value 0.46123720159465276
# epoch number94
#  epoch value 0.4612371929645988
# epoch number95
#  epoch value 0.4612371209300078
# epoch number96
#  epoch value 0.46123707177813167
# epoch number97
#  epoch value 0.46123702546840883
# epoch number98
#  epoch value 0.46123699373593885
# epoch number99
#  epoch value 0.46123699294315007

# %%
# MB-SGD with batch size b=64
lam = 1E-6 # do not change
b = 64 # do not change
stepsize = 0.1 # you must tune this parameter

w, objvals_mbsgd64 = mb_sgd(x_train, y_train, lam, b, stepsize)
# Out:
# epoch number0
#  epoch value 0.6463273499837404
# epoch number1
#  epoch value 0.5793072148574758
# epoch number2
#  epoch value 0.5469465774951154
# epoch number3
#  epoch value 0.5274960250438439
# epoch number4
#  epoch value 0.5153318040100663
# epoch number5
#  epoch value 0.5069577422118676
# epoch number6
#  epoch value 0.5005633166445222
# epoch number7
#  epoch value 0.4959357331090321
# epoch number8
#  epoch value 0.49235607124264813
# epoch number9
#  epoch value 0.48963931876559574
# epoch number10
#  epoch value 0.48737626113850147
# epoch number11
#  epoch value 0.4853806433113654
# epoch number12
#  epoch value 0.48385365006329983
# epoch number13
#  epoch value 0.4825602128763946
# epoch number14
#  epoch value 0.48153314294817207
# epoch number15
#  epoch value 0.48055340833217686
# epoch number16
#  epoch value 0.47983410301772567
# epoch number17
#  epoch value 0.4791465801570992
# epoch number18
#  epoch value 0.4785639293458249
# epoch number19
#  epoch value 0.47808497750683426
# epoch number20
#  epoch value 0.4776237778606486
# epoch number21
#  epoch value 0.47722075652556495
# epoch number22
#  epoch value 0.47688922922304916
# epoch number23
#  epoch value 0.47658709147263856
# epoch number24
#  epoch value 0.4763253236451009
# epoch number25
#  epoch value 0.47610031206406855
# epoch number26
#  epoch value 0.4759115574009384
# epoch number27
#  epoch value 0.47571904171760393
# epoch number28
#  epoch value 0.4755627944223592
# epoch number29
#  epoch value 0.4754136452790198
# epoch number30
#  epoch value 0.4752955132469877
# epoch number31
#  epoch value 0.47516155877473326
# epoch number32
#  epoch value 0.47505770891967414
# epoch number33
#  epoch value 0.47497963380077673
# epoch number34
#  epoch value 0.4748987803505423
# epoch number35
#  epoch value 0.474819897359232
# epoch number36
#  epoch value 0.4747608678970159
# epoch number37
#  epoch value 0.4746980983742496
# epoch number38
#  epoch value 0.4746472101015624
# epoch number39
#  epoch value 0.4745949080596873
# epoch number40
#  epoch value 0.47455494091322664
# epoch number41
#  epoch value 0.47452112688132575
# epoch number42
#  epoch value 0.47448162633350127
# epoch number43
#  epoch value 0.474459561153392
# epoch number44
#  epoch value 0.47442637255654596
# epoch number45
#  epoch value 0.47440377626280467
# epoch number46
#  epoch value 0.4743825186998151
# epoch number47
#  epoch value 0.4743640738507455
# epoch number48
#  epoch value 0.4743463860170377
# epoch number49
#  epoch value 0.47433091775255043
# epoch number50
#  epoch value 0.47431542359415735
# epoch number51
#  epoch value 0.4743028153750915
# epoch number52
#  epoch value 0.4742919743876671
# epoch number53
#  epoch value 0.4742810283034046
# epoch number54
#  epoch value 0.47427199093970585
# epoch number55
#  epoch value 0.4742629595457252
# epoch number56
#  epoch value 0.4742554824879287
# epoch number57
#  epoch value 0.47424914233766513
# epoch number58
#  epoch value 0.47424278161040856
# epoch number59
#  epoch value 0.4742364074832704
# epoch number60
#  epoch value 0.4742322753254891
# epoch number61
#  epoch value 0.4742279506697519
# epoch number62
#  epoch value 0.4742229410588322
# epoch number63
#  epoch value 0.4742198650061525
# epoch number64
#  epoch value 0.4742168866236517
# epoch number65
#  epoch value 0.4742139809994327
# epoch number66
#  epoch value 0.47421149183759387
# epoch number67
#  epoch value 0.4742087532384337
# epoch number68
#  epoch value 0.4742070052845623
# epoch number69
#  epoch value 0.47420479607437294
# epoch number70
#  epoch value 0.4742030581764922
# epoch number71
#  epoch value 0.47420165694159255
# epoch number72
#  epoch value 0.4742001408870453
# epoch number73
#  epoch value 0.4741990184045462
# epoch number74
#  epoch value 0.47419775740869446
# epoch number75
#  epoch value 0.47419688685782574
# epoch number76
#  epoch value 0.47419595650366714
# epoch number77
#  epoch value 0.4741951382833746
# epoch number78
#  epoch value 0.47419437330236436
# epoch number79
#  epoch value 0.4741937741993369
# epoch number80
#  epoch value 0.47419314123932504
# epoch number81
#  epoch value 0.47419257116368885
# epoch number82
#  epoch value 0.4741921446237959
# epoch number83
#  epoch value 0.47419170341792344
# epoch number84
#  epoch value 0.4741912537062444
# epoch number85
#  epoch value 0.4741909171764539
# epoch number86
#  epoch value 0.47419060571674
# epoch number87
#  epoch value 0.47419029438452
# epoch number88
#  epoch value 0.4741900471014754
# epoch number89
#  epoch value 0.4741898430863644
# epoch number90
#  epoch value 0.4741896156245799
# epoch number91
#  epoch value 0.4741894196218032
# epoch number92
#  epoch value 0.4741892394883461
# epoch number93
#  epoch value 0.4741890999968055
# epoch number94
#  epoch value 0.4741889524618502
# epoch number95
#  epoch value 0.47418884964464747
# epoch number96
#  epoch value 0.474188731358366
# epoch number97
#  epoch value 0.47418863132839223
# epoch number98
#  epoch value 0.4741885386734569
# epoch number99
#  epoch value 0.4741884678239348

# %% [markdown]
# # 7. Plot and compare GD, SGD, and MB-SGD

# %% [markdown]
# You are required to compare the following algorithms:
#
# - Gradient descent (GD)
#
# - SGD
#
# - MB-SGD with b=8
#
# - MB-SGD with b=64
#
# Follow the code in Section 4 to plot ```objective function value``` against ```epochs```. There should be four curves in the plot; each curve corresponds to one algorithm.

# %% [markdown]
# Hint: Logistic regression with $\ell_2$-norm regularization is a strongly convex optimization problem. All the algorithms will converge to the same solution. **In the end, the ``objective function value`` of the 4 algorithms will be the same. If not the same, your implementation must be wrong. Do NOT submit wrong code and wrong result!**

# %%
# plot the 4 curves:
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(20,10))

lineGD = range(len(objvals_gd))
lineSGD = range(len(objvals_sgd))
lineMBSGD8 = range(len(objvals_mbsgd8))
lineMBSGD64 = range(len(objvals_mbsgd64))

line1, = plt.plot(lineGD, objvals_gd, 'g')
line2, = plt.plot(lineSGD, objvals_sgd, 'r')
line3, = plt.plot(lineMBSGD8, objvals_mbsgd8, 'o')
line4, = plt.plot(lineMBSGD64, objvals_mbsgd64, 'b')
plt.xlabel('Epochs')
plt.ylabel('OBB Val')

plt.show()
